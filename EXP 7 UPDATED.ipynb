# %%
# !mamba install pandas
# Out:
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 3.187 seconds
#   Name           Version  Build                Channel
# --------------------------------------------------------------------
# + pandas         3.0.5    np23py313h1e705a5_0  emscripten-forge-4x
# + python-tzdata  2026.3   pyhd8ed1ab_0         conda-forge
# - pip            26.1.2   pyh145f28c_0         conda-forge

# %%
# !mamba install nltk
# Out:
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, nltk
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 2.224 seconds
#   Name        Version   Build            Channel
# --------------------------------------------------------------
# + click       8.4.2     pyhc90fa1f_0     conda-forge
# + defusedxml  0.7.1     pyhd8ed1ab_0     conda-forge
# + joblib      1.5.3     py313h1804a44_3  emscripten-forge-4x
# + nltk        3.10.3    pyhcf101f3_0     conda-forge
# + regex       2022.6.2  py313h6d8a2ba_3  emscripten-forge-4x
# + setuptools  84.0.0    pyh332efcf_0     conda-forge
# + tqdm        4.70.0    pyh8f84b5b_0     conda-forge

# %%
# !mamba install scikit-learn
# Out:
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, nltk, scikit-learn
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 2.249 seconds
#   Name                Version    Build                Channel
# ---------------------------------------------------------------------------
# + brotli-python       1.2.0      py313ha26e73d_2      emscripten-forge-4x
# + certifi             2026.7.22  pyhd8ed1ab_0         conda-forge
# + charset-normalizer  3.5.1      pyhd8ed1ab_0         conda-forge
# + idna                3.18       pyhcf101f3_0         conda-forge
# + narwhals            2.24.0     pyhcf101f3_0         conda-forge
# + pysocks             1.7.1      py313h1804a44_3      emscripten-forge-4x
# + requests            2.34.2     pyhcf101f3_0         conda-forge
# + scikit-learn        1.9.0      np23py313hb9816c2_0  emscripten-forge-4x
# + threadpoolctl       3.6.0      pyhecae5ae_0         conda-forge
# + urllib3             2.2.2      pyhd8ed1ab_0         conda-forge

# %%
# !mamba install seaborn
# Out:
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, nltk, scikit-learn, seaborn
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 1.634 seconds
#   Name          Version  Build                Channel
# -------------------------------------------------------------------
# + patsy         1.0.2    py313h1804a44_3      emscripten-forge-4x
# + seaborn       0.13.2   hd8ed1ab_3           conda-forge
# + seaborn-base  0.13.2   pyhd8ed1ab_3         conda-forge
# + statsmodels   0.14.6   np23py313hd8db738_2  emscripten-forge-4x

# %%
import numpy as np 
import pandas as pd
import re 
import nltk 
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import accuracy_score, precision_score, recall_score 
from sklearn.metrics import confusion_matrix, classification_report 
import matplotlib.pyplot as plt 
import seaborn as sns
print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# !mamba install pandas
# Out:
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, nltk, scikit-learn, seaborn
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 2.615 seconds
# All requested packages already installed.

# %%
df = pd.read_csv("Restaurant_Reviews.tsv", sep="\t")
print("Dataset loaded successfully!")
print(df.head())
# Out:
# Dataset loaded successfully!
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
print("First 5 rows:") 
display(df.head()) 
print("\nDataset Shape:", df.shape) 
print("\nColumn Names:", df.columns) 
print("\nDataset Information:") 
df.info() 
print("\nSentiment Distribution:") 
print(df["Liked"].value_counts())
# Out:
# First 5 rows:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1
# Dataset Shape: (1000, 2)
#
# Column Names: Index(['Review', 'Liked'], dtype='str')
#
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  1000 non-null   str
#  1   Liked   1000 non-null   int64
# dtypes: int64(1), str(1)
# memory usage: 11.8 KB
#
# Sentiment Distribution:
# Liked
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
# !mamba install nltk
# Out:
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, nltk, scikit-learn, seaborn
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 1.713 seconds
# All requested packages already installed.

# %%
import nltk

# %%
nltk.download("stopwords")  
print("Stopwords downloaded successfully!")
# Out:
# /lib/python3.13/site-packages/nltk/downloader.py:1076: UserWarning: NLTK will not authorize the non-private download directory '/home/web_user/nltk_data': it (or an ancestor) is world- or group-writable, so another local user could plant files there. Choose a private location such as ~/nltk_data.
#   for msg in self.incr_download(info_or_id, download_dir, force):
# [nltk_data] Error loading stopwords: Security Violation
# [nltk_data]     [pathsec.urlopen]: SSRF attempt to restricted IP
# [nltk_data]     172.29.1.0
# Stopwords downloaded successfully!

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# %%
import re
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

corpus = []
ps = PorterStemmer()

english_stopwords = set(ENGLISH_STOP_WORDS)

for i in range(len(df)):
    review = re.sub("[^a-zA-Z]", " ", df["Review"].iloc[i]).lower()
    words = review.split()
    words = [w for w in words if w not in english_stopwords]
    words = [ps.stem(w) for w in words]
    corpus.append(" ".join(words))

print("Preprocessing completed!")
print("\nFirst 10 processed reviews:")
print(corpus[:10])
# Out:
# Preprocessing completed!
#
# First 10 processed reviews:
# ['wow love place', 'crust good', 'tasti textur just nasti', 'stop late bank holiday rick steve recommend love', 'select menu great price', 'get angri want damn pho', 'honeslti didn t tast fresh', 'potato like rubber tell ahead time kept warmer', 'fri great', 'great touch']

# %%
cv = CountVectorizer(max_features=1500) 
X = cv.fit_transform(corpus).toarray() 
y = df.iloc[:, 1].values 
print("Feature matrix shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Feature matrix shape: (1000, 1490)
# Target shape: (1000,)

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.20, random_state=0 ) 
print("Training data shape:", X_train.shape)
print("Testing data shape:", X_test.shape)
# Out:
# Training data shape: (800, 1490)
# Testing data shape: (200, 1490)

# %%
model = RandomForestClassifier( n_estimators=35, random_state=42 ) 
model.fit(X_train, y_train) 
print("Random Forest model trained successfully!")
# Out:
# Random Forest model trained successfully!

# %%
model_score = model.score(X_test, y_test) 
print("Model Accuracy:", round(model_score * 100, 2), "%") 
y_pred = model.predict(X_test) 
print("Predictions completed!")
# Out:
# Model Accuracy: 71.0 %
# Predictions completed!

# %%
score1 = accuracy_score(y_test, y_pred) 
score2 = precision_score(y_test, y_pred, zero_division=0) 
score3 = recall_score(y_test, y_pred, zero_division=0) 
print("---- Scores ----")
print("Accuracy:", round(score1 * 100, 2), "%") 
print("Precision:", round(score2, 2)) 
print("Recall:", round(score3, 2))
# Out:
# ---- Scores ----
# Accuracy: 71.0 %
# Precision: 0.76
# Recall: 0.63

# %%
print("Classification Report:")
print(classification_report( y_test, y_pred, zero_division=0 ))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.79      0.73        97
#            1       0.76      0.63      0.69       103
#
#     accuracy                           0.71       200
#    macro avg       0.72      0.71      0.71       200
# weighted avg       0.72      0.71      0.71       200

# %%
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm) 
plt.figure(figsize=(5, 5)) 
sns.heatmap( cm, annot=True, fmt="d", cmap="YlGnBu", xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"] ) 
plt.xlabel("Predicted Values") 
plt.ylabel("Actual Values") 
plt.title("Random Forest Confusion Matrix") 
plt.show()
# Out:
# Confusion Matrix:
# [[77 20]
#  [38 65]]

# %%
best_accuracy = 0 
n_estimators_val = 5
print("Testing different n_estimators values...\n") 
for i in np.arange(1, 30, 2):
    temp_model = RandomForestClassifier(
        n_estimators=i,
        random_state=42
    )
    temp_model.fit(X_train, y_train) 
    temp_pred = temp_model.predict(X_test) 
    score = accuracy_score(y_test, temp_pred) 
    print( "n_estimators =", i, "Accuracy =", round(score * 100, 2), "%" )
    if score > best_accuracy: 
        best_accuracy = score 
        n_estimators_val = i
        print( "Best accuracy:", round(best_accuracy * 100, 2), "%", "with n_estimators =", n_estimators_val )
# Out:
# Testing different n_estimators values...
#
# n_estimators = 1 Accuracy = 65.0 %
# Best accuracy: 65.0 % with n_estimators = 1
# n_estimators = 3 Accuracy = 64.5 %
# n_estimators = 5 Accuracy = 68.0 %
# Best accuracy: 68.0 % with n_estimators = 5
# n_estimators = 7 Accuracy = 68.5 %
# Best accuracy: 68.5 % with n_estimators = 7
# n_estimators = 9 Accuracy = 71.0 %
# Best accuracy: 71.0 % with n_estimators = 9
# n_estimators = 11 Accuracy = 72.5 %
# Best accuracy: 72.5 % with n_estimators = 11
# n_estimators = 13 Accuracy = 72.5 %
# n_estimators = 15 Accuracy = 71.0 %
# n_estimators = 17 Accuracy = 71.5 %
# n_estimators = 19 Accuracy = 68.5 %
# n_estimators = 21 Accuracy = 72.0 %
# n_estimators = 23 Accuracy = 72.5 %
# n_estimators = 25 Accuracy = 72.0 %
# n_estimators = 27 Accuracy = 72.5 %
# n_estimators = 29 Accuracy = 71.0 %

# %%
model = RandomForestClassifier( n_estimators=n_estimators_val, random_state=42 ) 
model.fit(X_train, y_train) 
print("Optimized Random Forest Model:") 
print(model)
# Out:
# Optimized Random Forest Model:
# RandomForestClassifier(n_estimators=np.int32(11), random_state=42)

# %%
def predict_sentiment(sample_review): 
    review = re.sub("[^a-zA-Z]", " ", sample_review).lower() 
    words = review.split() 
    words = [w for w in words if w not in english_stopwords]
    words = [ps.stem(w) for w in words] 
    review = " ".join(words) 
    data = cv.transform([review]).toarray() 
    return model.predict(data)[0] 
sample_review = "The food is really good here."
prediction = predict_sentiment(sample_review) 
print("Review:", sample_review)
if prediction == 1: 
        print("This is a POSITIVE review.")
else:
    print("This is a NEGATIVE review!")
# Out:
# Review: The food is really good here.
# This is a POSITIVE review.

# %%
final_predictions = model.predict(X_test) 
accuracy = accuracy_score(y_test, final_predictions) 
precision = precision_score(y_test, final_predictions, zero_division=0) 
recall = recall_score(y_test, final_predictions, zero_division=0)
print("\n==========================================") 
print(" FINAL RANDOM FOREST MODEL PERFORMANCE") 
print("==========================================") 
print("Accuracy :", round(accuracy * 100, 2), "%") 
print("Precision:", round(precision, 2)) 
print("Recall   :", round(recall, 2)) 
print("Best n_estimators:", n_estimators_val)
# Out:
# ==========================================
#  FINAL RANDOM FOREST MODEL PERFORMANCE
# ==========================================
# Accuracy : 72.5 %
# Precision: 0.79
# Recall   : 0.63
# Best n_estimators: 11
